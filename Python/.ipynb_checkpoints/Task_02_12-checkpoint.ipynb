# %% [markdown]
# To Write the Python Code for Below Output
# -----------------------------------------

# %%
# Call the Function

oddEven([10, 12, 14, 11, 13, 15])

# %% [markdown]
# OutPut:
# -------
#
# Odd Number : 11, 13, 15
#
# Even Number : 10, 12, 14
