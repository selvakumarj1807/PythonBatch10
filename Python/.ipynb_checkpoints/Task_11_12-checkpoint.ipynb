# %% [markdown]
# # Oops Task:
# ------------

# %% [markdown]
# OutPut
# ------

# %%
Simple Ecommerce

1. Display Product
2. Borrow Product

Enter any One (1/2) : 1

Our Products - Apple, Orange, Banana 

1. Display Product
2. Borrow Product

Enter any One (1/2) : 2

Enter your borrow Product : Apple, Oranage

pay Amount : Apple 1kg, Orange 1Kg - Rs. 100
