# %% [markdown]
# # Oops Task:
# ------------

# %% [markdown]
# OutPut
# ------

# %%
Simple Ecommerce

1. Display Product
2. Borrow Product

Enter any One (1/2) : 1

Our Products - Apple, Orange, Banana 

1. Display Product
2. Borrow Product

Enter any One (1/2) : 2

Enter your borrow Product 01 Apple : 1
Enter your borrow Product 02 Orange : 2
Enter your borrow Product 03 Banana : 0

Apple - 1 - Rs. 50
Orange - 2 - Rs. 100
Banana - 0 - Rs. 0

Total - Rs. 150
