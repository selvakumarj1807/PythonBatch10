# %% [markdown]
# # To Write the Python Code For Below Output:
# --------------------------------------------

# %% [markdown]
# Question 01
# -----------
#
# gmail = admin@gmail.com

# %% [markdown]
# Output:
# -------
#
# Gmail : admin@gmail.com
#
# UserName : admin

# %% [markdown]
# Question 02
# -----------
#
# v1 = 'hi welcome python'

# %% [markdown]
# Output:
# -------
#
# Hi Welcome Python
#
# Index Position's (o) - 8, 16

# %% [markdown]
# Question 03:
# ------------
#
# gmail = 'gmail - admin@gmail.com'

# %% [markdown]
# speceial Charecters: 3
#
# space - 2
#
# a = 3
#
# e = 0
#
# i = 3
#
# o = 1
#
# u = 0
