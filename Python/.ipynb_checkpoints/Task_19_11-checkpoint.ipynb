# %% [markdown]
# # To write the Python Code for below Output
# -------------------------------------------

# %% [markdown]
# # 1.
# ----
#
# Output:
# -------
#
# Enter your Name: Sara
#
# Enter your Age: 25
#
# Hi Sara your age is 25. And your Date of Birth is 2000

# %% [markdown]
# # 2.
# ----
#
# Output:
# -------
#
# 1 X 2 = 2
#
# 2 X 2 = 4
#
# 3 X 2 = 6
#
# 4 X 2 = 8
#
# 5 X 2 = 10

# %% [markdown]
# # 3.
# ----
#
# Output:
# -------
#
# ['Sara', 25, 'sara@gmail.com', 9500912258]
#
# Sara your age is 25. So you are Eliguble for vote

# %% [markdown]
# # 4.
# ----
#
# Output:
# -------
#
# ['Sara', 25, 'sara@gmail.com', 9500912258]
#
# Sara your mobile number (9500912258) is Valid
